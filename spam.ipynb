# %% [markdown]
# <a href="https://colab.research.google.com/github/marankri/sakthimaran/blob/main/spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install gradio scikit-learn

# Import necessary libraries
import gradio as gr
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
import pandas as pd

# Prepare a simple dataset
data = {
    'text': [
        'Congratulations! You have won a lottery of $1000',
        'Hello, how are you?',
        'Click here to claim your prize',
        'Meeting at 10 AM tomorrow',
        'Free entry in a weekly competition',
        'Your invoice is attached',
        'Get paid for taking surveys',
        'See you at the conference next week'
    ],
    'label': ['spam', 'ham', 'spam', 'ham', 'spam', 'ham', 'spam', 'ham']
}

df = pd.DataFrame(data)

# Create and train the model
model = make_pipeline(CountVectorizer(), MultinomialNB())
model.fit(df['text'], df['label'])

# Define the prediction function
def predict_spam(message):
    prediction = model.predict([message])
    return "Spam" if prediction[0] == 'spam' else "Not Spam"

# Set up the Gradio interface
interface = gr.Interface(
    fn=predict_spam,
    inputs=gr.Textbox(label="Enter your message"),
    outputs=gr.Label(label="Prediction"),
    title="Spam Detection App",
    description="Type a message to check if it's spam or not."
)

# Launch the interface
interface.launch()
# Out:
# ERROR: Operation cancelled by user
#      <input type="file" id="files-d09e98c6-8d77-45d5-a5dc-e1904133e5cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d09e98c6-8d77-45d5-a5dc-e1904133e5cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
